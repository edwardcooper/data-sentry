# %% [markdown]
# The goal of this notebook is to create some fake PII data and merge it with some blog or news for training.

# %% [markdown]
# The generated PII type is SSN, Name (first or last name), address (street address or full address), email (personal or company), phone_number, credit card number, birthday.

# %%
from faker import Faker
from numpy.random import choice as choose
from numpy.random import seed as setseed

from tqdm import tqdm

from datetime import datetime

import pandas as pd



def sep_change(text, init_sep, after_sep):
    """
    A function to separate the input text into strings by the init_sep variable
    
    and combine the strings again by the after_sep variable.
    """
    splitted_strings = text.split(init_sep)
    
    combined_strings = after_sep.join(splitted_strings)
    
    return combined_strings

def convert_datetime_underscore(data):
    """
    A Helper function to convert all separators in datetime.now() into underscore. 
    """
    now_string = str(data)
    
    now_string = sep_change(now_string, init_sep = "-", after_sep = "_")
    
    now_string = sep_change(now_string, init_sep = " ", after_sep = "_")
    
    now_string = sep_change(now_string, init_sep = ":", after_sep = "_")
    
    now_string = sep_change(now_string, init_sep = ".", after_sep = "_")
    
    return now_string
    
def _random_sep_change(data, init_sep = "-", after_sep = " ", percentage = 0.5 , seed = 7):
    """
    A function to randomly change the SSN data's separator. 
    
    The input data is a list.
    """
    setseed(seed)
    # generate the index for replacing separator.
    replacing_indexes = choose(range(len(data)), int(len(data)*percentage))
    
    for each_replacing_index in replacing_indexes:
        # change the ssn data's separator from init_sep to after_sep
        data[each_replacing_index] = sep_change(data[each_replacing_index], init_sep, after_sep)
        
    return data
        

    
    

class Fake_PII():
    '''
    A class to generate a number of fake profiles, training/testing text mixed with
    different types of fake PIIs.
    '''
    def __init__(self, n_profile = None,fake_profiles = None, seed = 7,\
                pii_with_text = None, pii_labels = None, PII = None):

            
        
        # initialize the Faker from faker package for fake data generation.
        try:
            self.faker = Faker()
        except ImportError as error:
            print(error.__class__.__name__ + ": " + error.message)
            

        self.n_profile = n_profile
        self.pii_with_text = pii_with_text
        self.pii_labels = pii_labels
        self.fake_profiles = fake_profiles
        self.seed = seed 
        self.PII = PII 
 
        
    def create_fake_profile(self, n_profile, verbose = False, ssn_sep_change = True):
        
        assert isinstance(n_profile, int), "Please enter an integer\
        for the number of generated profiles."
        self.n_profile = n_profile
        
        fake_profiles = dict()
        # use faker package to generate either a full/last name/first name.
        fake_profiles["Name"] = [choose([self.faker.name(),\
                                         self.faker.last_name(),
                                         self.faker.first_name()])\
                                 for _ in range(self.n_profile)]
        # use faker to generate either a full/secondary/street address
        fake_profiles["Address"] = [choose([self.faker.address(),\
                                            self.faker.street_address(),\
                                            self.faker.secondary_address()])\
                                   for _ in range(self.n_profile)]
        
        fake_profiles["SSN"] = [self.faker.ssn() for _ in range(self.n_profile)]
        
        fake_profiles["Email"] = [self.faker.email() for _ in range(self.n_profile)]
                                 
        fake_profiles["Plates"] = [self.faker.license_plate()\
                                   for _ in range(self.n_profile)]
                                        
        
        fake_profiles["CreditCardNumber"] = [self.faker.credit_card_number()\
                                             for _ in range(self.n_profile)]
                                     
        
        fake_profiles["Phone_number"] = [self.faker.phone_number()\
                                         for _ in range(self.n_profile)]
        
        # change the separator in SSN data.
        if ssn_sep_change:
            fake_profiles["SSN"] = _random_sep_change(fake_profiles["SSN"])
                                        
        # change the separator in Address data from "/n" to " "
        fake_profiles['Address'] = [sep_change(each_address, init_sep = "\n" , after_sep = " ")\
                                   for each_address in fake_profiles['Address'] ]
                                              
        
        
        self.fake_profiles = fake_profiles
        
        if verbose:
            return self.fake_profiles 
        
    def _init_pii_gen_train(self):
        
        # generate the all possible PII implemented in the create_fake_profile methods
        self._fake_labels = list(self.fake_profiles.keys())
        
        # generate the None labels 
        self._none_pii_labels = ["None" for _ in range(self._n_text)]
        
        # generate the pii labels
        self.pii_labels = sorted(self._fake_labels*self._n_text)
        
        # generate the test with no pii
        self._fake_text_no_pii = [self.faker.paragraph() for _ in range(self._n_text)]
        
        # mutiply the no pii text with the number of PII types
        self._init_fake_text_no_pii = self._fake_text_no_pii*len(self._fake_labels)     
        
        # initialize the text mixed with PII with all "None" strings. 
        self.pii_with_text = ["None" for _ in range(len(self._fake_labels)*(self._n_text))]
        
        # initialize the PII with all "None" strings
        self.PII = ["None" for _ in range(self._n_text*(len(self._fake_labels)+1))]
        
    def _random_pii_insert(self):
        # randomly insert PII into the text
        for index, PII in enumerate(tqdm(self.pii_labels)):
            # choose a PII value from the dictionary according to the PII type.
            PII_value = choose(self.fake_profiles[PII])
            
            original_fake_text = self._init_fake_text_no_pii[index]
            
            tokenized_fake_text = original_fake_text.split(" ")
            
            # generate the position to fill in the PII value
            PII_position = choose(range(len(tokenized_fake_text)+1))
            
            tokenized_fake_text.insert(PII_position, PII_value)
            
            one_text_mixed_with_PII = " ".join(tokenized_fake_text)
            
            self.pii_with_text[index] = one_text_mixed_with_PII
            self.PII[index] = PII_value
        
    
    def create_pii_text_train(self, n_text = 10):
        """
        A method to create the training text randomly mixed with fake PII. This
        method creates a text and mixed it with different kinds of PII, which leads
        to a total number of (num_of_PII)*(n_text) rows.
        
        """
        warning_text = "Please create fake profiles first with .create_fake_profile method."
        assert self.fake_profiles is not None, warning_text
        
        self._n_text = n_text
        # initialized a few variables for inserting PII values 
        self._init_pii_gen_train()
        
        # randomly insert Pii text into the paragraph.
        self._random_pii_insert()
        
        
        self.pii_with_text.extend(self._fake_text_no_pii)
        self.pii_labels.extend(self._none_pii_labels)
        
   
        
        return self.pii_labels, self.pii_with_text, self.PII
        
    def _init_pii_gen_test(self):
        
        # generate the all possible PII implemented in the create_fake_profile methods
        self._fake_labels = list(self.fake_profiles.keys())
        
        # generate the None labels 
        self._none_pii_labels = ["None" for _ in range(self._n_text)]
        
        # generate the pii labels
        self.pii_labels = sorted(self._fake_labels*self._n_text)  
        
        total_num_pii_text = (1+len(self._fake_labels))*(self._n_text)
        # generate the fake text with no pii
        self._init_fake_text_no_pii = [self.faker.paragraph() for _ in range(total_num_pii_text)]
        
        # initialize the text mixed with PII with all "None" strings. 
        self.pii_with_text = self._init_fake_text_no_pii
        # initialize the PII with all "None" strings
        self.PII = ["None" for _ in range(total_num_pii_text)]
        
    
    def create_pii_text_test(self, n_text = 10):
        """
        A method to create the testing text randomly mixed with fake PII. 
        This method creates a text and mixed it with a type of PII. 
        
        In the training text, a normal text is repeated used to insert different PIIs into
        it. In the testing text, a normal text is not intentionally repeated to insert 
        different PIIs. 
        
        """
        warning_text = "Please create fake profiles first with .create_fake_profile method."
        assert self.fake_profiles is not None, warning_text
        
        self._n_text = n_text
        
        # initialized a few variables for inserting PII values 
        self._init_pii_gen_test()
        
        # randomly insert Pii text into the paragraph.
        self._random_pii_insert()
        # add the none labels 
        self.pii_labels.extend(self._none_pii_labels)
       
        return self.pii_labels, self.pii_with_text, self.PII

# %%
fake_ = Fake_PII()
fake_.create_fake_profile(10)
train_labels, train_text, train_PII = fake_.create_pii_text_train(n_text = 10)
test_labels, test_text, test_PII = fake_.create_pii_text_test(n_text = 10)
# Out:
# 100%|██████████| 70/70 [00:00<00:00, 35023.41it/s]
# 100%|██████████| 70/70 [00:00<00:00, 37010.12it/s]

# %%
train_text_with_pii = pd.DataFrame({"Text":train_text, "Labels":train_labels, "PII":train_PII})
train_file_name = "train_text_with_pii_" + convert_datetime_underscore(datetime.now()) + ".csv"
train_text_with_pii.to_csv(train_file_name,index=False)





test_text_with_pii = pd.DataFrame({"Text":test_labels, "Labels":test_text, "PII":test_PII})
test_file_name = "test_text_with_pii_" + convert_datetime_underscore(datetime.now()) + ".csv"
test_text_with_pii.to_csv(test_file_name,index=False)

# %%
train_text
# Out:
# ['Maybe site begin pass relationship natural style. Suite 927 Full actually arrive house someone per understand.',
#  'Have specific top already under part avoid. 25468 Matthew Village Theresaland, AR 06964 Sit state south film east.',
#  'Ahead bank several nothing product chair. Per probably eat 6958 Julie Harbors Apt. 486 take kid measure.',
#  'Instead many appear beautiful now. Within candidate 6958 Julie Harbors Apt. 486 great alone task general ever. Indeed like bar.',
#  'Analysis our policy produce 56342 William Isle direction morning. Trade energy newspaper price. Too he five daughter.',
#  'Card point particularly table imagine exactly. Office 7047 Raymond Stream Suite 912 Port Stephen, RI 57413 identify civil sign rich form wish. Stay type to under somebody include individual ability.',
#  'When feeling hair fund bill. Let card team meeting already start. 7047 Raymond Stream Suite 912 Port Stephen, RI 57413 Impact wear single start respond.',
#  'Subject but study language toward. Industry Suite 927 theory company rule individual. Decade picture better evening too support.',
#  'Mission voice hope foreign see artist way. Every idea sort article so Apt. 893 sound. Large should why director bar training board service.',
#  'Catch tend report little continue. That vote hold 3576 Davis Extension Suite 359 maintain itself movement affect true.',
#  'Maybe site begin pass relationship natural style. 5266437982583777 Full actually arrive house someone per understand.',
#  '676161251563 Have specific top already under part avoid. Sit state south film east.',
#  'Ahead bank 582102647028 several nothing product chair. Per probably eat take kid measure.',
#  'Instead many appear beautiful now. Within candidate great alone 5266437982583777 task general ever. Indeed like bar.',
#  'Analysis our policy produce 3526823311192151 direction morning. Trade energy newspaper price. Too he five daughter.',
#  'Card point particularly 5172225577125994 table imagine exactly. Office identify civil sign rich form wish. Stay type to under somebody include individual ability.',
#  'When feeling hair fund bill. Let card team 3594510054984228 meeting already start. Impact wear single start respond.',
#  'Subject but study language toward. Industry theory company rule individual. Decade picture better evening too support. 3594510054984228',
#  '4694718030901409 Mission voice hope foreign see artist way. Every idea sort article so sound. Large should why director bar training board service.',
#  'Catch tend report little continue. That 582102647028 vote hold maintain itself movement affect true.',
#  'Maybe site begin pass relationship natural style. djenkins@best.com Full actually arrive house someone per understand.',
#  'Have specific top robertmathis@beasley.net already under part avoid. Sit state south film east.',
#  'Ahead bank several nothing product chair. Per georgemiller@hotmail.com probably eat take kid measure.',
#  'Instead many appear beautiful now. Within candidate great alone task general ever. djenkins@best.com Indeed like bar.',
#  'djenkins@best.com Analysis our policy produce direction morning. Trade energy newspaper price. Too he five daughter.',
#  'Card point particularly table antonio67@yahoo.com imagine exactly. Office identify civil sign rich form wish. Stay type to under somebody include individual ability.',
#  'When megan82@gmail.com feeling hair fund bill. Let card team meeting already start. Impact wear single start respond.',
#  'Subject megan82@gmail.com but study language toward. Industry theory company rule individual. Decade picture better evening too support.',
#  'Mission voice hope foreign megan82@gmail.com see artist way. Every idea sort article so sound. Large should why director bar training board service.',
#  'Catch megan82@gmail.com tend report little continue. That vote hold maintain itself movement affect true.',
#  'Maybe site begin pass relationship King natural style. Full actually arrive house someone per understand.',
#  'Have King specific top already under part avoid. Sit state south film east.',
#  'Ahead bank several Fields nothing product chair. Per probably eat take kid measure.',
#  'Instead many Fields appear beautiful now. Within candidate great alone task general ever. Indeed like bar.',
#  'Analysis our policy produce direction morning. Trade Jason Harris energy newspaper price. Too he five daughter.',
#  'Card point particularly table imagine exactly. Office identify civil sign rich Mack form wish. Stay type to under somebody include individual ability.',
#  'When feeling hair fund bill. Let card team meeting already start. Impact Karen wear single start respond.',
#  'Subject but study language toward. Industry theory company rule King individual. Decade picture better evening too support.',
#  'Mission voice hope foreign see artist way. Every idea sort article so sound. Large Mack should why director bar training board service.',
#  'Catch tend report little continue. Jessica Schmidt That vote hold maintain itself movement affect true.',
#  '613.951.9248 Maybe site begin pass relationship natural style. Full actually arrive house someone per understand.',
#  'Have specific top already under part avoid. Sit state south film 948.013.9924 east.',
#  'Ahead bank several nothing product chair. Per probably eat take (843)852-4383x177 kid measure.',
#  'Instead many appear beautiful now. Within candidate great alone task general 001-782-911-4967 ever. Indeed like bar.',
#  'Analysis our policy produce direction morning. Trade energy newspaper price. Too he five 001-388-680-2806 daughter.',
#  'Card point particularly table imagine exactly. Office 001-864-561-1553x6447 identify civil sign rich form wish. Stay type to under somebody include individual ability.',
#  'When feeling hair fund bill. Let card team meeting already start. Impact 613.951.9248 wear single start respond.',
#  'Subject but study language toward. Industry (843)852-4383x177 theory company rule individual. Decade picture better evening too support.',
#  'Mission voice hope foreign see artist 049.898.2887x33574 way. Every idea sort article so sound. Large should why director bar training board service.',
#  'Catch tend report little continue. That vote hold maintain itself movement affect 049.898.2887x33574 true.',
#  'Maybe UJA-914 site begin pass relationship natural style. Full actually arrive house someone per understand.',
#  'Have specific top already 6YE 755 under part avoid. Sit state south film east.',
#  'Ahead bank several nothing product chair. Per probably eat 5ZR 477 take kid measure.',
#  'Instead many appear beautiful now. Within candidate great alone task general ever. Indeed UWS-3761 like bar.',
#  'Analysis our policy produce direction morning. Trade energy newspaper price. Too he GBG W23 five daughter.',
#  'Card point 98X•766 particularly table imagine exactly. Office identify civil sign rich form wish. Stay type to under somebody include individual ability.',
#  'When feeling hair fund bill. Let card team 98X•766 meeting already start. Impact wear single start respond.',
#  'Subject but study language toward. Industry theory company rule individual. IFO-498 Decade picture better evening too support.',
#  'Mission voice hope foreign see artist way. Every idea sort article so sound. Large should why director 5ZR 477 bar training board service.',
#  'Catch tend report little continue. That vote hold maintain itself 98X•766 movement affect true.',
#  'Maybe site begin pass relationship 408-16-3092 natural style. Full actually arrive house someone per understand.',
#  'Have specific top already under part 408-16-3092 avoid. Sit state south film east.',
#  'Ahead bank several nothing product chair. Per probably 518 94 2803 eat take kid measure.',
#  'Instead many appear beautiful now. Within candidate great alone task general ever. Indeed like bar. 805 19 3539',
#  'Analysis our policy produce direction morning. Trade energy newspaper 684-40-2127 price. Too he five daughter.',
#  'Card point particularly table imagine exactly. Office identify civil sign rich form wish. Stay type to under somebody include individual ability. 003-93-1559',
#  'When feeling hair fund bill. Let card team meeting already start. Impact 678 26 0624 wear single start respond.',
#  'Subject but study language toward. Industry theory company rule individual. Decade 518 94 2803 picture better evening too support.',
#  'Mission 805 19 3539 voice hope foreign see artist way. Every idea sort article so sound. Large should why director bar training board service.',
#  'Catch tend report little continue. 684-40-2127 That vote hold maintain itself movement affect true.',
#  'Maybe site begin pass relationship natural style. Full actually arrive house someone per understand.',
#  'Have specific top already under part avoid. Sit state south film east.',
#  'Ahead bank several nothing product chair. Per probably eat take kid measure.',
#  'Instead many appear beautiful now. Within candidate great alone task general ever. Indeed like bar.',
#  'Analysis our policy produce direction morning. Trade energy newspaper price. Too he five daughter.',
#  'Card point particularly table imagine exactly. Office identify civil sign rich form wish. Stay type to under somebody include individual ability.',
#  'When feeling hair fund bill. Let card team meeting already start. Impact wear single start respond.',
#  'Subject but study language toward. Industry theory company rule individual. Decade picture better evening too support.',
#  'Mission voice hope foreign see artist way. Every idea sort article so sound. Large should why director bar training board service.',
#  'Catch tend report little continue. That vote hold maintain itself movement affect true.']

# %%
test_text
# Out:
# ['Friend his those run probably seek our. Trial same century conference matter 6958 Julie Harbors Apt. 486 economy fight. Yard others something.',
#  'Sometimes myself only detail own. Occur his Suite 772 stock peace. From including down attorney special relationship.',
#  'Everybody machine through simple will. Live wonder former identify. 3576 Davis Extension Suite 359',
#  'Fact close 56342 William Isle get machine election section. Go authority attention.',
#  'Stock feeling life mean. Certain 7047 Raymond Stream Suite 912 Port Stephen, RI 57413 various research administration upon another matter.',
#  'Apt. 893 Behavior medical plan full. Scene dinner its know her.',
#  'None health practice she old especially. Continue 3576 Davis Extension Suite 359 evening base bad. Clearly cost read.',
#  'Away happen shake region. Standard middle indeed answer. Method organization become red feel. 3268 Teresa Plaza East Cassandra, HI 22259',
#  'Off upon blue west 6958 Julie Harbors Apt. 486 great capital contain. Few consumer admit group say car.',
#  'Enough method watch hand beautiful real nearly. Weight expect series 25468 Matthew Village Theresaland, AR 06964 anything leg become knowledge. Economic year open summer. Idea before including particular.',
#  'After put 582102647028 both shake without prepare. Difference until sort southern lawyer high. Full notice operation skill.',
#  'Meet company situation able store. Help 582102647028 although image subject everyone anything. Tax next every top education film.',
#  'Teacher owner strong science candidate find. Anything within prepare 213150753498837 by design. Animal defense environment.',
#  'Little amount and similar. This 5172225577125994 learn drop data prepare evening kid most.',
#  'Machine board rather low action development focus animal. Able if either sport reality general relationship. 4694718030901409',
#  '582102647028 Determine cell thing south identify six doctor. Easy collection such rock type.',
#  'Smile 5172225577125994 bring old. Person physical without admit.',
#  '4694718030901409 Figure future because bring stop process rule. Career carry author. Former vote vote improve example chance ten.',
#  'Prove build tonight green. Wide another whose south drive plant 6554707631732887 past major.',
#  'Defense recently listen artist support box improve. Party become dream nation have. Position president our south evidence yourself so. Million then can hot 5266437982583777 particularly western.',
#  'Prepare trouble remain couple. wrightashley@stevens.com Well once state official tree.',
#  'Mr reach fall old possible wear. Magazine what contain actually leg find robertmathis@beasley.net bag.',
#  'Hope detail order mouth worry. Agency megan82@gmail.com history these election consider space.',
#  'Young djenkins@best.com expert voice manager guy civil practice. Behind player tell. Occur group door quickly.',
#  'Power task georgemiller@hotmail.com although something run. Visit risk close.',
#  'Clearly measure bit require low civil fine. Stock difficult part chance free. djenkins@best.com Receive similar hit person night join.',
#  'georgemiller@hotmail.com Fact through style experience culture effect those. Test land ask shake phone however act get. Agent ahead never people year.',
#  'Training trip appear television machine happy physical. Mention activity news room from. Allow baby robertmathis@beasley.net remember politics imagine poor relate.',
#  'Answer different christophercohen@juarez.com factor painting avoid try way. Staff record create thank actually occur. Contain loss letter manage western agency.',
#  'Every go glass industry drop scientist. Likely recently walk trip once georgemiller@hotmail.com animal box.',
#  'Half moment person catch idea Jason Harris success might. Together student major save also magazine.',
#  'Karen Throw believe poor establish position. Hour hotel issue.',
#  'This international accept him. Deborah Us pull writer. Energy as grow show.',
#  'Control discover important imagine much. Future subject cut fly test entire hundred. Jason Harris',
#  'Model face Mrs before. Officer value example happen public follow Norma Koch itself.',
#  'Jessica Schmidt Chance seat culture condition game decision. Result move fish quality free whatever.',
#  'Different realize look method Taylor American feel.',
#  'Fields Toward west first however table. Mrs million such oil arrive form truth recently.',
#  'However too PM friend interview nearly future. Billion real Mack perhaps worker still. Method difficult market region step indeed both. Operation money rise summer debate concern.',
#  'Personal memory hot Deborah health history want. Decade remember against marriage participant again.',
#  'Defense 001-388-680-2806 voice world apply specific. Congress social notice popular. Apply about worry group reduce surface.',
#  'Church (164)750-6452x6754 chance stuff how easy since letter someone. Natural system fire someone at. Wall yeah show take movie loss.',
#  'Unit work crime year land such. 948.013.9924 Year deal almost. Nearly second science.',
#  'Down record media today poor his respond. Tree letter kind maintain baby else beautiful. +1-153-933-2197x935 Later partner majority community themselves window practice. Public final hair fear they usually.',
#  'Foot (164)750-6452x6754 entire throw student black leg. Argue certainly close blood writer.',
#  'And (164)750-6452x6754 alone cut debate along miss. Rule story resource whatever.',
#  'Security (843)852-4383x177 amount herself drive wall evidence still ground. Game consider instead according. Bag stop building choice between.',
#  'Bad of world least ready. Trouble impact miss 001-782-911-4967 start ago measure.',
#  'Change own 049.898.2887x33574 color cost civil. West ball let hold. Use in right whole me attorney and.',
#  'Join floor indicate man move court. Half 948.013.9924 phone for him office.',
#  'Far their smile clearly. Wall price rather rich set time court. 5ZR 477',
#  'Outside national HIU 641 bad physical.',
#  'Lot personal result both view 5VH5838 push western. Car room adult event.',
#  'Leg feeling process us plan memory take candidate. Weight IFO-498 simply community.',
#  'However organization 98X•766 knowledge news western Mrs director down. History allow perhaps list cost.',
#  'Talk explain end second source 6YE 755 discuss.',
#  'Point least eat. Figure poor clearly 6YE 755 difficult tend. Wonder hot specific.',
#  'Next ever small really. International community deep since laugh fund. GBG W23 Management cold plant action but little military.',
#  'Need image finish. Another heavy machine forget perform when low. Yard whom media have 98X•766 which car fly.',
#  'Plan defense member speech especially. Office total learn might reason. Help adult source those. 5ZR 477 Member so information admit president themselves after friend.',
#  'Capital organization 805 19 3539 experience group particularly I born. Century suffer address federal participant.',
#  'Particular from practice interest week writer decision. However 805 19 3539 future direction serious. Wrong here see million.',
#  '003-93-1559 Hold worker population as recognize such stock. Leg during shoulder management.',
#  'House item current coach left. Purpose little purpose 684-40-2127 some act occur fund. Game three manager away staff direction some Republican.',
#  'Data visit recognize brother until radio. Activity thousand hundred feel generation might 518 94 2803 economy. Risk he prevent house sport gun.',
#  'We would service forward actually. Nice trouble 003-93-1559 test either industry class part address. Site remain rich decide trouble.',
#  'Than computer 805 19 3539 billion make mean scientist. Despite time do service often.',
#  'Situation she raise clear. Peace for 684-40-2127 girl maybe.',
#  'Worry pick mission onto various court. Ball fact blood none. Within today foot couple 408-16-3092 alone fly.',
#  'Onto later future 518 94 2803 car issue to ball. Hand particularly cost wear ever since. Both space really force start across.',
#  'Hot smile should national travel. Left physical sound evening course good night. Expect no hard model page.',
#  'Go drive poor make. Rock skill voice size. Reveal bring seem score able plant good.',
#  'Point north modern edge candidate investment sit. Address leave able. Top value skin boy. Hear civil mother recent unit various.',
#  'Face at stop social somebody job leader. Five sea find think it arm movie well. According agent national close institution ready well.',
#  'Stock although strong skill budget attention charge. Hope information baby knowledge. Structure once continue why gas.',
#  'At rather special entire several. Research although structure politics time. Responsibility production the but life school.',
#  'Travel international thus edge wear. I American north former. Girl window ready challenge.',
#  'A high money responsibility fund brother black. Add media since. Security visit team response keep north us Mrs.',
#  'Although recent either skill owner property authority. Training arm Mrs where successful if. Place class good sister. Police decade hit.',
#  'Thought ball east protect very middle or food.']
